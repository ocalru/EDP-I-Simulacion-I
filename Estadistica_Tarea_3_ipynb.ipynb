# %% [markdown]
# <a href="https://colab.research.google.com/github/ocalru/EDP-I-Simulacion-I/blob/main/Estadistica_Tarea_3_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  <p align="center">
#     <font size="10" color="red"> Ejercicio 1: </font>
# </p>

# %% [markdown]
# - $ TOEFL ∼ 𝑁(510, 70²) $
# - $ IQ ∼ 𝑁(112, 15²) $
# - Suposición: las variables son independientes.
#
# Estandarizando las variables:
#
# $$
# Z = \frac{X - \mu}{\sigma}
# $$
#
# El valor de **500** puntos representa el **puntaje mínimo requerido** para que un estudiante extranjero sea considerado para la admisión según el criterio del examen **TOEFL**. Como la distribución de puntajes TOEFL se modela como una distribución normal con media $ \mu = 510 $ y desviación estándar $ \sigma = 70 $, estandarizamos este puntaje para calcular la probabilidad de que un estudiante supere este umbral. ( $TOEFL ≥ 500$):
#
# $$
# Z_{TOEFL} = \frac{500 - 510}{70} = -0.1429
# $$
#
# $$
# P(TOEFL \geq 500) = P(Z \geq -0.1429) = 1 - P(Z < -0.1429) \approx 1 - 0.4432 = 0.5568
# $$
#
#
#
# El valor de **102** puntos representa el **puntaje mínimo requerido** en la prueba de inteligencia (IQ) para que un estudiante extranjero sea considerado en el proceso de admisión. La distribución de resultados en esta prueba se modela como una normal con media $ \mu = 112 $ y desviación estándar $ \sigma = 15 $. Estandarizamos este valor para determinar qué porcentaje de estudiantes alcanza o supera este umbral. ($ IQ ≥ 102: $)
#
# $$
# Z_{IQ} = \frac{102 - 112}{15} = -0.6667
# $$
#
#  <p align="center">
#     <font size="4" color="red"> Calculando la probabilidad de que un alumno pase la prueba TOEFL: </font>
# </p>
#
#
#
# $$
# P(TOEFL \geq 500) = P(Z \geq -0.1429)
# $$
#
# Este valor representa la **probabilidad de que un estudiante saque al menos $ 500$ puntos en el examen TOEFL**, es decir, que **cumpla con el requisito mínimo** para ser admitido.
#
# Para calcular esta probabilidad, usamos la tabla de la distribución normal estándar, que da los valores acumulados **hasta cierto valor $Z$**, es decir, $ P(Z < z) $.
#
# Entonces:
#
# $$
# P(Z \geq -0.1429) = 1 - P(Z < -0.1429)
# $$
#
# - $ P(Z < -0.1429) $ representa la **proporción de estudiantes que obtienen una puntuación menor a 500** en el TOEFL, es decir, **los que no pasan el examen**.
#
# - Al hacer $ 1 - P(Z < -0.1429) $, estamos calculando la **proporción complementaria**, es decir, **los estudiantes que sí lo pasan**.
#
# Aproximando con la tabla:
#
# $$
# P(Z < -0.1429) \approx 0.4432
# $$
#
# $$
# P(Z \geq -0.1429) = 1 - 0.4432 = 0.5568
# $$
#
# Por lo tanto, **aproximadamente el $ 55.68 \% $ de los estudiantes extranjeros cumplen el requisito del TOEFL**.
#
#  <p align="center">
#     <font size="4" color="red"> Calculando la probabilidad de que un alumno pase la prueba IQ: </font>
# </p>
#
#
# $$
# P(IQ \geq 102) = P(Z \geq -0.6667)
# $$
#
# Este valor representa la **probabilidad de que un estudiante obtenga al menos $ 102 $ puntos en la prueba de IQ**, es decir, que **cumpla con el puntaje mínimo requerido** para ser considerado en el proceso de admisión.
#
# Para encontrar esta probabilidad, usamos la distribución normal estándar, que nos da la probabilidad acumulada de que un valor Z esté **por debajo** de cierto umbral.
#
# Entonces:
#
# $$
# P(Z \geq -0.6667) = 1 - P(Z < -0.6667)
# $$
#
# - $ P(Z < -0.6667) $ representa la **proporción de estudiantes que tienen un IQ menor a 102**, es decir, **los que no alcanzan el puntaje requerido**.
#
# - Al hacer $ 1 - P(Z < -0.6667) $, obtenemos la **probabilidad de que un estudiante tenga un IQ de 102 o más**, es decir, **los que sí pasan el criterio de admisión por IQ**.
#
# Buscando en la tabla:
#
# $$
# P(Z < -0.6667) \approx 0.2525
# $$
#
# $$
# P(Z \geq -0.6667) = 1 - 0.2525 = 0.7475
# $$
#
# Así, **aproximadamente el $ 74.75 \% $ de los estudiantes cumplen con el requisito de IQ mínimo para ser admitidos**.
#
#
#  <p align="center">
#     <font size="4" color="red"> a) Calculo de la probabiliad de que pasan exactamente una de las dos pruebas: </font>
# </p>
#
#
#
#
# Queremos calcular la probabilidad de que **un estudiante pase exactamente una de las dos pruebas**, es decir:
#
# - Que **pase TOEFL pero no IQ**: $ A \cap \neg B $
# - Que **pase IQ pero no TOEFL**: $ \neg A \cap B $
#
# $$
# P(\text{exactamente una}) = P(A \cap \neg B) + P(\neg A \cap B)
# $$
#
# Donde:
#
# - $ A $: el estudiante **pasa TOEFL** (es decir, $ TOEFL ≥ 500 $ )
# - $ \neg A $: el estudiante **no pasa TOEFL**
# - $ B $: el estudiante **pasa IQ** (es decir,$ IQ ≥ 102 $)
# - $ \neg B $: el estudiante **no pasa IQ**
#
#
#
# Estamos sumando **dos casos mutuamente excluyentes**:
#
# 1. Que pase TOEFL pero no IQ
# 2. Que pase IQ pero no TOEFL
#
# Estos dos eventos **no se pueden dar al mismo tiempo**, por lo tanto, la probabilidad total de “pasar exactamente una” es la **suma de las probabilidades** de ambos escenarios.
#
#
#
# Cuando decimos $ P(A \cap \neg B) $, nos referimos a la probabilidad de que **ocurran ambas cosas al mismo tiempo**:
#
# - Que el estudiante **sí pase TOEFL**
# - Y que el estudiante **no pase IQ**
#
# De forma similar, $ P(\neg A \cap B) $ representa que:
#
# - **No pasa TOEFL**
# - **Sí pasa IQ**
#
#
#
# $$
# P(A \cap \neg B) = P(A) \cdot P(\neg B)
# $$
# $$
# P(\neg A \cap B) = P(\neg A) \cdot P(B)
# $$
#
# Esto es válido **porque se nos dice que las variables TOEFL e IQ son independientes**. Es decir, **el resultado en un examen no afecta el resultado del otro**. Por eso podemos usar la regla:
#
# $$
# P(X \cap Y) = P(X) \cdot P(Y) \quad \text{si X e Y son independientes}
# $$
#
#
#
# Sustituyendo valores:
#
# $$
# P(A) = 0.5568, \quad P(B) = 0.7475
# $$
# $$
# P(\neg B) = 1 - P(B) = 0.2525, \quad P(\neg A) = 1 - P(A) = 0.4432
# $$
#
# $$
# P(\text{exactamente una}) = 0.5568 \cdot 0.2525 + 0.4432 \cdot 0.7475
# $$
# $$
# = 0.1406 + 0.3315 = \boxed{0.4721 \text{ (47.21%)}}
# $$
#
# Esto significa que **aproximadamente el $ 47.21 \% $ de los estudiantes pasan exactamente una de las dos pruebas**.
#
#  <p align="center">
#     <font size="4" color="red"> b) Pasan ambas pruebas </font>
# </p>
#
#
#
# $$
# P(\text{ambas}) = P(A \cap B) = P(A) \cdot P(B) = 0.5568 \cdot 0.7475 = \boxed{0.4162 \text{ (41.62%)}}
# $$
#
#  <p align="center">
#     <font size="4" color="red"> c) Pasan al menos una de las dos pruebas </font>
# </p>
#
#
#
#
# Queremos calcular la probabilidad de que **un estudiante pase al menos una** de las dos pruebas (TOEFL o IQ). En notación de conjuntos, esto se expresa como:
#
# $$
# P(A \cup B)
# $$
#
# Donde:
# - El estudiante **pasa TOEFL** (evento $ A $)
# - El estudiante **pasa IQ** (evento $ B $)
# - El estudiante pasa **ambas** pruebas (evento $ A \cap B $)
#
# Es decir, estamos contando **todos los casos posibles** en los que el estudiante **pasa al menos una** de las dos pruebas.
#
# $$
# P(A \cup B) = P(A) + P(B) - P(A \cap B)
# $$
#
# Cuando se suma directamente $ P(A) + P(B) $, estamos **contando dos veces** a los estudiantes que pasan ambas pruebas (porque están en $ A $ **y** en $ B $). Para **evitar ese doble conteo**, restamos una vez la intersección:
#
# - $ P(A) $: probabilidad de pasar TOEFL
# - $ P(B) $: probabilidad de pasar IQ
# - $ P(A \cap B) $: probabilidad de pasar ambas pruebas
#
# Entonces:
#
# $$
# P(\text{al menos una}) = P(\text{TOEFL}) + P(\text{IQ}) - P(\text{ambas})
# $$
#
# Sustituyendo los valores:
#
# $$
# P(A) = 0.5568, \quad P(B) = 0.7475, \quad P(A \cap B) = P(A) \cdot P(B) = 0.5568 \cdot 0.7475 \approx 0.4162
# $$
#
# $$
# P(A \cup B) = 0.5568 + 0.7475 - 0.4162 = 0.8881
# $$
#
#  <p align="center">
#     <font size="4" color="red">  d) No pasan alguna de las dos pruebas
#  </font>
# </p>
#
#
# Esto es el complemento de c):
#
# $$
# P(\text{no pasa alguna de las 2}) = 1 - P(A \cup B) = 1 - 0.8881 = 0.1119 \approx 11.19\%
# $$
#
#
#  <p align="center">
#     <font size="4" color="red">  e) ¿A partir de qué puntuación de IQ están el 10% más inteligentes? </font>
# </p>
#
#
#
# Buscamos el percentil 90 de la distribución $ N(112, 15^2) $
#
# $$
# Z_{0.90} = 1.2816
# $$
#
# $$
# X = \mu + Z\sigma = 112 + 1.2816 \cdot 15 = \boxed{131.22}
# $$

# %% [markdown]
#  <p align="center">
#     <font size="10" color="red"> Ejercicio 2: </font>
# </p>

# %% [markdown]
# Se supone que la cantidad de horas de sueño diaria de adultos sanos sigue una **distribución normal**. En un estudio se encontró que:
#
# - El 30% de los adultos duerme menos de 7.2 horas por día.
# - El 40% de los adultos duerme menos de 7.5 horas por día.
#
# Queremos encontrar la **media** ($ \mu $) y la **desviación estándar** ($ \sigma $)) de dicha distribución.
#
# Sean:
#
# - $ X_1 = 7.2 $ con probabilidad $ P(X < X_1) = 0.30 \Rightarrow z_1 = -0.524 $
# - $ X_2 = 7.5 $ con probabilidad $ P(X < X_2) = 0.40 \Rightarrow z_2 = -0.253 $
#
# Usamos la fórmula de la normal estándar:
#
# $$
# X = \mu + z\sigma
# $$
#
# Entonces, planteamos el siguiente sistema:
#
# $$
# X_1 = \mu + z_1\sigma \Rightarrow 7.2 = \mu - 0.524\sigma \tag{1}
# $$
# $$
# X_2 = \mu + z_2\sigma \Rightarrow 7.5 = \mu - 0.253\sigma \tag{2}
# $$
#
#
# Resolución del sistema:
#
# Restamos ($ 2 $) menos ($ 1 $):
#
# $$
# (7.5 - 7.2) = (\mu - 0.253\sigma) - (\mu - 0.524\sigma)
# $$
# $$
# 0.3 = (0.271)\sigma
# \Rightarrow \sigma = \frac{0.3}{0.271} \approx 1.107
# $$
#
# Sustituimos $ \sigma $ en la ecuación ($ 1 $):
#
# $$
# 7.2 = \mu - 0.524(1.107) \Rightarrow \mu = 7.2 + 0.580 \approx 7.78
# $$
#
# Entonces se tiene que:
#
# - **Media $ \mu \approx 7.78 $ horas**
# - **Desviación estándar $ \sigma \approx 1.11 $ horas**

# %% [markdown]
#  <p align="center">
#     <font size="10" color="red"> Ejercicio 3: </font>
# </p>

# %% [markdown]
# Se sabe que:
#
# - El 25% de las tareas toma **más de 80 minutos**
#   $ \Rightarrow P(X > 80) = 0.25 \Rightarrow P(X < 80) = 0.75 \Rightarrow z_1 = z_{0.75} \approx 0.674 $
#
# - El 10% de las tareas toma **más de 100 minutos**
#   $ \Rightarrow P(X > 100) = 0.10 \Rightarrow P(X < 100) = 0.90 \Rightarrow z_2 = z_{0.90} \approx 1.282 $
#
#
# Se usa la formula:
#
# $$
# X = \mu + z\sigma
# $$
#
# Entonces:
#
# $$
# X_1 = 80 = \mu + 0.674\sigma \tag{1}
# $$
# $$
# X_2 = 100 = \mu + 1.282\sigma \tag{2}
# $$
#
#
#
# Restamos ($2$) menos ($1$):
#
# $$
# (100 - 80) = (1.282 - 0.674)\sigma
# \Rightarrow 20 = 0.608\sigma
# \Rightarrow \sigma = \frac{20}{0.608} \approx 32.89
# $$
#
# Sustituimos en ($1$):
#
# $$
# 80 = \mu + 0.674(32.89)
# \Rightarrow \mu = 80 - 22.16 \approx 57.84
# $$
#
#  Cálculo de la probabilidad $ P(70 < X < 100) $:
#
# Usamos:
#
# $$
# Z = \frac{X - \mu}{\sigma}
# $$
#
# Para $ X = 70 $:
#
# $$
# Z = \frac{70 - 57.84}{32.89} \approx 0.37
# \Rightarrow P(Z < 0.37) \approx 0.644
# $$
#
# Para $ X = 100 $:
#
# $$
# Z = \frac{100 - 57.84}{32.89} \approx 1.282
# \Rightarrow P(Z < 1.282) \approx 0.900
# $$
#
# Entonces:
#
# $$
# P(70 < X < 100) = P(Z < 1.282) - P(Z < 0.37) \approx 0.900 - 0.644 = 0.256
# $$
