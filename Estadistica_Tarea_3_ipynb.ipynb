# %% [markdown]
# <a href="https://colab.research.google.com/github/ocalru/EDP-I-Simulacion-I/blob/main/Estadistica_Tarea_3_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  <p align="center">
#     <font size="10" color="lightblue"> Ejercicio 1: </font>
# </p>

# %% [markdown]
# - $ TOEFL ∼ 𝑁(510, 70²) $
# - $ IQ ∼ 𝑁(112, 15²) $
# - Suposición: las variables son independientes.
#
# Estandarizando las variables:
#
# $$
# Z = \frac{X - \mu}{\sigma}
# $$
#
# El valor de **500** puntos representa el **puntaje mínimo requerido** para que un estudiante extranjero sea considerado para la admisión según el criterio del examen **TOEFL**. Como la distribución de puntajes TOEFL se modela como una distribución normal con media $ \mu = 510 $ y desviación estándar $ \sigma = 70 $, estandarizamos este puntaje para calcular la probabilidad de que un estudiante supere este umbral. ( $TOEFL ≥ 500$):
#
# $$
# Z_{TOEFL} = \frac{500 - 510}{70} = -0.1429
# $$
#
# $$
# P(TOEFL \geq 500) = P(Z \geq -0.1429) = 1 - P(Z < -0.1429) \approx 1 - 0.4432 = 0.5568
# $$
#
#
#
# El valor de **102** puntos representa el **puntaje mínimo requerido** en la prueba de inteligencia (IQ) para que un estudiante extranjero sea considerado en el proceso de admisión. La distribución de resultados en esta prueba se modela como una normal con media $ \mu = 112 $ y desviación estándar $ \sigma = 15 $. Estandarizamos este valor para determinar qué porcentaje de estudiantes alcanza o supera este umbral. ($ IQ ≥ 102: $)
#
# $$
# Z_{IQ} = \frac{102 - 112}{15} = -0.6667
# $$
#
# $$
# P(TOEFL \geq 500) = P(Z \geq -0.1429)
# $$
#
# Este valor representa la **probabilidad de que un estudiante saque al menos $ 500$ puntos en el examen TOEFL**, es decir, que **cumpla con el requisito mínimo** para ser admitido.
#
# Para calcular esta probabilidad, usamos la tabla de la distribución normal estándar, que da los valores acumulados **hasta cierto valor $Z$**, es decir, $ P(Z < z) $.
#
# Entonces:
#
# $$
# P(Z \geq -0.1429) = 1 - P(Z < -0.1429)
# $$
#
# - $ P(Z < -0.1429) $ representa la **proporción de estudiantes que obtienen una puntuación menor a 500** en el TOEFL, es decir, **los que no pasan el examen**.
#
# - Al hacer $ 1 - P(Z < -0.1429) $, estamos calculando la **proporción complementaria**, es decir, **los estudiantes que sí lo pasan**.
#
# Aproximando con la tabla:
#
# $$
# P(Z < -0.1429) \approx 0.4432
# $$
#
# $$
# P(Z \geq -0.1429) = 1 - 0.4432 = 0.5568
# $$
#
# Por lo tanto, **aproximadamente el $ 55.68 \% $ de los estudiantes extranjeros cumplen el requisito del TOEFL**.
#
# $$
# P(IQ \geq 102) = P(Z \geq -0.6667)
# $$
#
# Este valor representa la **probabilidad de que un estudiante obtenga al menos $ 102 $ puntos en la prueba de IQ**, es decir, que **cumpla con el puntaje mínimo requerido** para ser considerado en el proceso de admisión.
#
# Para encontrar esta probabilidad, usamos la distribución normal estándar, que nos da la probabilidad acumulada de que un valor Z esté **por debajo** de cierto umbral.
#
# Entonces:
#
# $$
# P(Z \geq -0.6667) = 1 - P(Z < -0.6667)
# $$
#
# - $ P(Z < -0.6667) $ representa la **proporción de estudiantes que tienen un IQ menor a 102**, es decir, **los que no alcanzan el puntaje requerido**.
#
# - Al hacer $ 1 - P(Z < -0.6667) $, obtenemos la **probabilidad de que un estudiante tenga un IQ de 102 o más**, es decir, **los que sí pasan el criterio de admisión por IQ**.
#
# Buscando en la tabla:
#
# \[
# P(Z < -0.6667) \approx 0.2525
# \]
#
# \[
# P(Z \geq -0.6667) = 1 - 0.2525 = 0.7475
# \]
#
# Así, **aproximadamente el 74.75% de los estudiantes cumplen con el requisito de IQ mínimo para ser admitidos**.
#
# ---
#
# ## Paso 2: Probabilidades
#
# ### a) Pasan exactamente una de las dos pruebas
#
# \[
# P(\text{exactamente una}) = P(A \cap \neg B) + P(\neg A \cap B)
# \]
#
# \[
# = P(A)(1 - P(B)) + (1 - P(A))P(B)
# \]
#
# \[
# = 0.5568 \cdot 0.2525 + 0.4432 \cdot 0.7475 \approx 0.1406 + 0.3315 = \boxed{0.4721 \text{ (47.21%)}}
# \]
#
# ---
#
# ### b) Pasan ambas pruebas
#
# \[
# P(\text{ambas}) = P(A \cap B) = P(A) \cdot P(B) = 0.5568 \cdot 0.7475 = \boxed{0.4162 \text{ (41.62%)}}
# \]
#
# ---
#
# ### c) Pasan al menos una de las dos pruebas
#
# \[
# P(A \cup B) = P(A) + P(B) - P(A \cap B)
# \]
#
# \[
# = 0.5568 + 0.7475 - 0.4162 = \boxed{0.8881 \text{ (88.81%)}}
# \]
#
# ---
#
# ### d) No pasan ninguna de las dos pruebas
#
# \[
# P(\text{ninguna}) = 1 - P(A \cup B) = 1 - 0.8881 = \boxed{0.1119 \text{ (11.19%)}}
# \]
#
# ---
#
# ### e) ¿A partir de qué puntuación de IQ están el 10% más inteligentes?
#
# Buscamos el percentil 90 de la distribución \( N(112, 15^2) \)
#
# \[
# Z_{0.90} = 1.2816
# \]
#
# \[
# X = \mu + Z\sigma = 112 + 1.2816 \cdot 15 = \boxed{131.22}
# \]
